# %%
import os
import time
import requests
from concurrent.futures import ThreadPoolExecutor

def download_file(url, filename):
    response = requests.get(url, stream=True)
    with open(filename, "wb") as f:
        for chunk in response.iter_content(chunk_size=8192):
            f.write(chunk)

def download_chunk(url, start, end, filename):
    headers = {'Range': f'bytes={start}-{end}'}
    response = requests.get(url, headers=headers, stream=True)
    print(start, end)
    if response.status_code == 206:
        with open(filename, "wb") as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)

def multi_threaded_download(url, num_threads=4):
    response = requests.head(url)
    file_size = int(response.headers['content-length'])
    chunk_size = file_size // num_threads
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = []
        for i in range(num_threads):
            start = i * chunk_size
            end = start + chunk_size - 1
            if i == num_threads - 1:
                end = file_size - 1
            part_filename = f'part_{i}.tmp'
            futures.append(executor.submit(download_chunk, url, start, end, part_filename))
        for future in futures:
            future.result()

    with open("output_file_mt", "wb") as final_file:
        for i in range(num_threads):
            part_filename = f'part_{i}.tmp'
            with open(part_filename, "rb") as part_file:
                final_file.write(part_file.read())
            os.remove(part_filename)

def single_thread_download(url):
    download_file(url, "output_file_st")

# 测试链接和下载
url = 'http://ipv4.download.thinkbroadband.com/100MB.zip'

start_time = time.time()
single_thread_download(url)
single_time = time.time() - start_time

start_time = time.time()
multi_threaded_download(url)
multi_time = time.time() - start_time

print(f"Single-threaded download time: {single_time} seconds")
print(f"Multi-threaded download time: {multi_time} seconds")
# Out:
# 052428800 78643199
# 26214400 52428799
# 78643200 104857599
#  26214399
# Single-threaded download time: 36.02476406097412 seconds
# Multi-threaded download time: 39.993539571762085 seconds

# %%
# Usage example
url = 'YOUR_DOWNLOAD_URL_HERE'
multi_threaded_download(url)

# %%
a = '''
Restaurants
Takeout
Delivery
Reservations
Burgers
Home Services
Contractors
Electricians
Home Cleaners
HVAC
Shopping
Nightlife
Active Life
Beauty & Spas
Automotive
Usual Search
'''
print(a.split('\n'))
# Out:
# ['', 'Restaurants', 'Takeout', 'Delivery', 'Reservations', 'Burgers', 'Home Services', 'Contractors', 'Electricians', 'Home Cleaners', 'HVAC', 'Shopping', 'Nightlife', 'Active Life', 'Beauty & Spas', 'Automotive', 'Usual Search', '']

# %%
import Celestial-Vault
# Out:
#   Cell In[7], line 1
#     import Celestial-Vault
#                     ^
# SyntaxError: invalid syntax

# %%
import httpx
import urllib.parse

# 设置请求头
headers = {
    "Accept": "text/html, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Cookie": "eng_k55_id=015106; Ecp_ClientId=n240530105000408699; firstEnterUrlInSession=https%3A//www.cnki.net/index/; Ecp_IpLoginFail=240530167.220.232.161; VisitorCapacity=1; ASP.NET_SessionId=eo1ucf3cp2lx30ttvijeph52; pageReferrInSession=https%3A//www.cnki.net/index/; knsLeftGroupSelectItem=1%3B2%3B; CurrSortField=Relevance%2frelevant%2c(%e5%8f%91%e8%a1%a8%e6%97%b6%e9%97%b4%2c%27time%27)+desc; CurrSortFieldType=desc; Ecp_ClientIp=-1; dblang=ch; tfstk=f4ZmC-M8drubS19Oiumf4HiO2q_-lIisa5Kt6chNzblWMIKYQf4ggS0ZWtGTZ1VuCjrOhOiMb7wEBrhxHODZaS0TXtt9hzNLLnEAlcKicciN96IdvKwjfcSPmxoEG8ySQr9Hzw2bhc95FbXqq-Tg8IBFncPZ43ksQckqghWkavGy0A-qQQWoCblZbq-aULknQCkZ3jLpbXqaVuWpyoS_UzZYqx0PJ-lyRjronqcU3oxwbdMmoXyqZ6pGT90zCVq6Ch0L3yNsLSRVsfZuUozUT_LxgyDgpPVhYhM7uSqrSuB1x8nmI2oZrd-aE0lZ-onFYQD7z-UacSvMbxZYvVcIrO-sW0rK8yPDC9wr0APsRlCBcjyadkaKxiAInzynqgyXzellIhMPBu865qkSEX1XSyvkPZ-3UTXkRZgqFxCdETY65qkSEXBlEeOjuYMA9",
    "Host": "www.cnki.net",
    "Origin": "https://www.cnki.net",
    "Referer": "https://www.cnki.net/kns/defaultresult/index",
    "Sec-Ch-Ua": '"Chromium";v="124", "Microsoft Edge";v="124", "Not-A.Brand";v="99"',
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": '"Windows"',
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
    "X-Requested-With": "XMLHttpRequest"
}

# 设置请求 payload
payload = {
    "IsSearch": True,
    "QueryJson": "{\"Platform\":\"\",\"DBCode\":\"CFLS\",\"KuaKuCode\":\"CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFN\",\"QNode\":{\"QGroup\":[{\"Key\":\"Subject\",\"Title\":\"\",\"Logic\":1,\"Items\":[{\"Title\":\"Subject\",\"Name\":\"SU\",\"Value\":\"糖尿病\",\"Operate\":\"%\",\"BlurType\":\"\"}],\"ChildItems\":[]}]},\"CodeLang\":\"ch\"}",
    "PageName": "defaultresult",
    "DBCode": "CFLS",
    "KuaKuCodes": "CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFN",
    "CurPage": 1,
    "RecordsCntPerPage": 20,
    "CurDisplayMode": "listmode",
    "CurrSortField": "",
    "CurrSortFieldType": "desc",
    "IsSentenceSearch": False,
    "Subject": ""
}

# 将payload转换为URL编码的字符串
encoded_payload = urllib.parse.urlencode(payload)

# 发送POST请求
response = httpx.post('https://www.cnki.net/kns/Brief/GetGridTableHtml', headers=headers, data=encoded_payload)

# 输出响应内容
print(response.text)
# Out:
# <form method="post" name="gridTableForm">
#     <div id="gridTable" class="search-result">
# <div class='toolbar'><div id="countPageDiv" class="result-con-r"><span class='pagerTitleCell'>Total:<em>518,956</em>  articles</span><span class='countPageMark'>1/300</span><span class='topTurnSpan'><a id='Page_next_top' title='“← →” Turn Page' data-curPage='2'>>></a></span></div><div class='toolbar-col toolbar-oth'>
#         <div class="checkcount">
#             <label class="checkAll"><input type="checkbox" name="selectCheckbox" id="selectCheckAll1"  onclick="$(this).filenameClick()">All</label>
#             <span>Selected:</span>
#             <em title='Click to check selected literature' id='selectCount' name='selectCount' onclick='window.open(APPPATH + "/manage.html?subject="+GetQueryStringByName("subject"))'tabindex="0" >0</em>
#             <a href="javascript:$.filenameClear();">Clear</a>
#           </div>
#           <div class="toolbar-mod">
#             <ul class="dropdown-analysis-btns" id="batchOpsBox">
#               <!--<li class="bulkdownload export"><a href="javascript:void(0)">Batch Download</a></li>-->
#               <li>
#                   <a href="javascript:void(0)">Export and Analysis</a><i class="icon-d"></i>
#                   <ul>
#                     <li class="export">
#                       <a href="javascript:void(0)">Export Reference</a>
#                       <i class="icon-r"></i>
#                       <ul class="secondUl">
#                         <li><a href="javascript:void(0)" exportType="GBTREFER" >GB/T 7714-2015 Citation</a></li>
#                         <li><a href="javascript:void(0)" exportType="REFER" >CAJ-CD Citation</a></li>
#                         <li><a href="javascript:void(0)" exportType="MLA" >MLA</a></li>
#                         <li><a href="javascript:void(0)" exportType="APA" >APA</a></li>
#                         <li><a href="javascript:void(0)" exportType="NEW" >Novelty Search(citation format)</a></li>
#                         <li><a href="javascript:void(0)" exportType="newdefine" >Novelty Search(self-defined)</a></li>
#                         <li><a href="javascript:void(0)" exportType="Refworks" >Refworks</a></li>
#                         <li><a href="javascript:void(0)" exportType="EndNote" >EndNote</a></li>
#                         <li><a href="javascript:void(0)" exportType="NoteExpress" >NoteExpress</a></li>
#                         <li><a href="javascript:void(0)" exportType="NodeFirst" >NoteFirst</a></li>
#                         <li><a href="javascript:void(0)" exportType="selfDefine" >Self-defined</a></li>
#                       </ul>
#                     </li>
#                     <li id="analysisLi">
#                       <a href="javascript:void(0)">Visual Analysis</a><i class="icon-r"></i>
#                       <ul class="secondUl">
#                         <li id="anisys_select"><a href="javascript:void(0)">Analysis of Selected Results(<span>0</span>)</a></li>
#                         <li id="anisys_all"><a href="javascript:void(0)">Analysis of All Search Results</a></li>
#                       </ul>
#                     </li>
#
#                   </ul>
#                 </li>
#               </ul>
#           <ul class="change-list" id="DivDisplayMode"><li  title="detail" data-obj="result-piclist" data-mode="custommode"><i class="icon-detail"></i></li><li class="active" title="list" data-obj="result-table-list" data-mode="listmode"><i class="icon-table"></i></li></ul><div class="statistic"><div id="id_grid_display_num"  class="page-show-count">Records/Page<div class="sort" id="perPageDiv"><div class="sort-default"><span>20</span><i class="icon icon-sort"></i></div><ul class="sort-list"><li  data-val="10"><a href="javascript:void(0);">10</a></li><li data-val="20" class="cur"><a href="javascript:void(0);" >20</a></li> <li  data-val="50"><a href="javascript:void(0);" >50</a></li></ul></div></div></div><div class="order-group" id="sortList"><span> Sort:</span><ul class="order" id="orderList"><li class='descend cur' title='Only valid within 8 million records' data-k="RELEVANT" data-sorttype="relevant%2c(%e5%8f%91%e8%a1%a8%e6%97%b6%e9%97%b4%2c%27time%27)" data-sort="RELEVANT-Relevance%2frelevant%2c(%e5%8f%91%e8%a1%a8%e6%97%b6%e9%97%b4%2c%27time%27)" data-onlydesc="true">Relevance</li><li data-sorttype="(%e5%8f%91%e8%a1%a8%e6%97%b6%e9%97%b4%2c%27TIME%27)"  data-k="PT"  data-sort="PT-Publication+Date%2f(%e5%8f%91%e8%a1%a8%e6%97%b6%e9%97%b4%2c%27TIME%27)" data-onlydesc="false">Publication Date</li><li data-sorttype="(%e8%a2%ab%e5%bc%95%e9%a2%91%e6%ac%a1%2c%27integer%27)"  data-k="CITY"  data-sort="CITY-Cites%2f(%e8%a2%ab%e5%bc%95%e9%a2%91%e6%ac%a1%2c%27integer%27)" data-onlydesc="false">Cites</li><li data-sorttype="(%e4%b8%8b%e8%bd%bd%e9%a2%91%e6%ac%a1%2c%27integer%27)"  data-k="DOWNLOAD"  data-sort="DOWNLOAD-Downloads%2f(%e4%b8%8b%e8%bd%bd%e9%a2%91%e6%ac%a1%2c%27integer%27)" data-onlydesc="false">Downloads</li><li data-sorttype="relevant%2cffd"  data-k="ALL"  data-sort="ALL-Overall%2frelevant%2cffd" data-onlydesc="true">Overall</li></ul></div></div></div></div><table class="result-table-list"> <thead><tr><th></th><th>Title</th><th>Author</th><th>Source</th><th>Publication Date</th><th>Database</th><th>Cites</th><th>Downloads</th><th>Options</th></tr></thead><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=1 name=CookieName  value="CAPJLAST!XHYX20240523001!1!0"  onclick="$(this).filenameClick()"  >1</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=1&recid=&FileName=XHYX20240523001&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=11.5882.r.20240528.1102.006' target='_blank'>Guideline for the Management of Diabetes Mellitus in the Elderly in China (2024 edition)</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       National Center of Gerontology;Chinese Society of Geriatrics;Diabetes Professional Committee of Chinese Aging Well Association;GUO Lixin;XIAO Xinhua
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=XHYX'>Medical Journal of Peking Union Medical College Hospital</a>
#
#
#       </td>
#       <td class="date">
#         2024-05-28 15:22
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>178</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWV6FGaOtGdYhmN0IHV3d3djNVNJh3QvlXd0AHNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dXHYX20240523001' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="XHYX20240523001"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=2 name=CookieName  value="CAPJLAST!JFJY20240515001!2!0"  onclick="$(this).filenameClick()"  >2</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=2&recid=&FileName=JFJY20240515001&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=11.1056.R.20240520.2003.004' target='_blank'>Diabetes burden in China from 1999 to 2019</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#            <span class="markOricon" title="English Full Text (Machine Translation)">English Full Text (MT)</span>
#
#
#      </td>
#       <td class="author">
#
#       Li Zan;Liu Xi-Yang;He Zhuo-Jia;Ma Shuang
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=JFJY'>Medical Journal of Chinese People's Liberation Army</a>
#
#
#       </td>
#       <td class="date">
#         2024-05-21 14:42
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>449</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVJlHOzgHevoUcoJne0o1Lzg2UhtGbzImdaFWNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dJFJY20240515001' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="JFJY20240515001"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=3 name=CookieName  value="CAPJLAST!LZXB2024041900A!3!0"  onclick="$(this).filenameClick()"  >3</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=3&recid=&FileName=LZXB2024041900A&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=21.1543.R.20240511.1802.002' target='_blank'>Discussion on the treatment for Diabetes Mellitus with modification of Guizhi Decoction</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       WAN Haiping;GONG Xuan;CAI Haobin;CAI Tiantian;LIN Songjun
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=LZXB'>Journal of Liaoning University of Traditional Chinese Medicine</a>
#
#
#       </td>
#       <td class="date">
#         2024-05-13 15:00
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>184</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVDljWoVVVPFVYqdXSU9kU0BVcZJGaJhVNU1GNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dLZXB2024041900A' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="LZXB2024041900A"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=4 name=CookieName  value="CAPJLAST!LNZY20240430001!4!0"  onclick="$(this).filenameClick()"  >4</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=4&recid=&FileName=LNZY20240430001&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=21.1128.r.20240430.1342.002' target='_blank'>Treatment of diabetic kidney disease from the spleen based on the theory of "spleen circulation and transfusion balance”</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#            <span class="markOricon" title="English Full Text (Machine Translation)">English Full Text (MT)</span>
#
#
#      </td>
#       <td class="author">
#
#       Zhou Cheng;Yang Yu-feng;An Ji-ren;Sun Gui-yan;Guan Ming-dan;Yu Jia-xiang;Shi Yan
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=LNZY'>Liaoning Journal of Traditional Chinese Medicine</a>
#
#
#       </td>
#       <td class="date">
#         2024-04-30 16:29
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>383</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVyMHTRdmNyRmW0lUZup2c0g1LMVkSDhWZN1GNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dLNZY20240430001' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="LNZY20240430001"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=5 name=CookieName  value="CAPJLAST!QKYX20240408001!5!0"  onclick="$(this).filenameClick()"  >5</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=5&recid=&FileName=QKYX20240408001&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=13.1222.R.20240409.1502.002' target='_blank'>Risk Factors,Prognosis and Rapid Screening in Patients with Acute Aortic Dissection Complicated with Type 2 Diabetes</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       HUANG Lujie;ZHANG Xiaoying;YU Shasha
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=QKYX'>Chinese General Practice</a>
#
#
#       </td>
#       <td class="date">
#         2024-04-11 16:22
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>179</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVzIVaLdDZRlXWjdXZDN1biJUaSVWU3FVVQlHNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-read"  target="online_open" href='/kns/Detail/Read?domain=tablename%3dCAPJLAST%26filename%3dQKYX20240408001%26dbCode%3dCAPJ' title="Read online"><i></i></a>
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="QKYX20240408001"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=6 name=CookieName  value="CAPJLAST!ZSFX20240314001!6!0"  onclick="$(this).filenameClick()"  >6</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=6&recid=&FileName=ZSFX20240314001&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=11.3495.R.20240318.1618.003' target='_blank'>Research Progress of Traditional Chinese Medicine Treatment for Diabetes and Its Complications：A Review</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       CAI Rushuang;YI Yan
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=ZSFX'>Chinese Journal of Experimental Traditional Medical Formulae</a>
#
#
#       </td>
#       <td class="date">
#         2024-03-19 11:02
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>3631</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVEhnRw02RSZHUBFUU5JmbXdXOCFTUWhXcaBHNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dZSFX20240314001' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="ZSFX20240314001"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=7 name=CookieName  value="CAPJLAST!ZYYL20230911002!7!0"  onclick="$(this).filenameClick()"  >7</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=7&recid=&FileName=ZYYL20230911002&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=51.1188.R.20230912.1546.002' target='_blank'>Progress in Animal Models of Type 2 Diabetes with Disease-Zheng(证) Combination</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#            <span class="markOricon" title="English Full Text (Machine Translation)">English Full Text (MT)</span>
#
#
#      </td>
#       <td class="author">
#
#       GU Jiaqi;QIN Lilan;XU Qiang
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=ZYYL'>Pharmacology and Clinics of Chinese Materia Medica</a>
#
#
#       </td>
#       <td class="date">
#         2023-09-13 16:01
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>1760</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWViFEW4cWZGJWdqBFW5pkeRZFWEF3ZWh3caBHNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dZYYL20230911002' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="ZYYL20230911002"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=8 name=CookieName  value="CAPJLAST!YLBS20230527001!8!0"  onclick="$(this).filenameClick()"  >8</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=8&recid=&FileName=YLBS20230527001&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=11.1155.R.20230530.0909.002' target='_blank'>Studies on pathophysiological characteristics of mice with diabetes combined with SARS-CoV-2 Spike protein infection</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#            <span class="markOricon" title="English Full Text (Machine Translation)">English Full Text (MT)</span>
#
#
#      </td>
#       <td class="author">
#
#       SU Xiao-yue;LI Jing-xuan;LIN Ying;ZHANG Yong-xiang;XIAO Zhi-yong;ZHOU Wen-xia
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=YLBS'>Chinese Journal of Pharmacology and Toxicology</a>
#
#
#       </td>
#       <td class="date">
#         2023-05-30 10:08
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>900</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVhRzazRkalJFSaN2V2RjYClkVyQDSvJWRn9GNvRjZXNHMZFFZxUVezUmezhkWopFNyRETR9Gc6FXdGBDb&tablename=CAPJLAST" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCAPJ%26filename%3dYLBS20230527001' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="YLBS20230527001"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=9 name=CookieName  value="CAPJLAST!ZPWL20200923004!9!0"  onclick="$(this).filenameClick()"  >9</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=9&recid=&FileName=ZPWL20200923004&DbName=CAPJLAST&DbCode=CAPJ&yx=Y&pr=&URLID=51.1505.r.20200923.1046.010' target='_blank'>Clinical features of bacterial liver abscess with diabetes</a>
#
#
#           <B class="marktip">Online First</B>
#
#
#
#           <B class="cMarkSign">Revoke</B>
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       GUO Mingfeng;ZHOU Bing
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CAPJ&BaseID=ZPWL'>Chinese Journal of Bases and Clinics in General Surgery</a>
#
#
#       </td>
#       <td class="date">
#         2020-09-24 09:05
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#           143
#
#       </td>
#       <td class="operat">
#
#
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CAPJ" data-filename="ZPWL20200923004"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=10 name=CookieName  value="CJFD2011!ZGSQ201136121!10!0"  onclick="$(this).filenameClick()"  >10</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=10&recid=&FileName=ZGSQ201136121&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'><font class=Mark>糖尿病</font>患者骨密度变化的相关因素分析</a>
#
#
#
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       王希武
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=ZGSQ'>Chinese Community Doctors</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e7%b3%96%e5%b0%bf%e7%97%85%e6%82%a3%e8%80%85%e9%aa%a8%e5%af%86%e5%ba%a6%e5%8f%98%e5%8c%96%e7%9a%84%e7%9b%b8%e5%85%b3%e5%9b%a0%e7%b4%a0%e5%88%86%e6%9e%90&scode=ZGSQ201136121' target="_blank">4</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>237</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVHBDOY9mZ5EDZJVFdhRlbQF2TadTa4NmWv1ENjZFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dZGSQ201136121' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="ZGSQ201136121"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=11 name=CookieName  value="CJFD2011!DDYI201136114!11!0"  onclick="$(this).filenameClick()"  >11</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=11&recid=&FileName=DDYI201136114&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'>中西医结合治疗<font class=Mark>糖尿病</font>膀胱的效果</a>
#
#
#
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       林连辉
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=DDYI'>Contemporary Medicine</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e4%b8%ad%e8%a5%bf%e5%8c%bb%e7%bb%93%e5%90%88%e6%b2%bb%e7%96%97%e7%b3%96%e5%b0%bf%e7%97%85%e8%86%80%e8%83%b1%e7%9a%84%e6%95%88%e6%9e%9c&scode=DDYI201136114' target="_blank">6</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>228</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVxYFWwFEeN5WaoJXVVBndsJXYzJ2L3plc4IDetVFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dDDYI201136114' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="DDYI201136114"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=12 name=CookieName  value="CJFD2011!GAYX201124031!12!0"  onclick="$(this).filenameClick()"  >12</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=12&recid=&FileName=GAYX201124031&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'>同型半胱氨酸和超敏C反应蛋白检测在<font class=Mark>糖尿病</font>合并脑梗死中的价值</a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      </td>
#       <td class="author">
#
#       叶润清;吴晓蔓
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=GAYX'>Guangdong Medical Journal</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e5%90%8c%e5%9e%8b%e5%8d%8a%e8%83%b1%e6%b0%a8%e9%85%b8%e5%92%8c%e8%b6%85%e6%95%8fC%e5%8f%8d%e5%ba%94%e8%9b%8b%e7%99%bd%e6%a3%80%e6%b5%8b%e5%9c%a8%e7%b3%96%e5%b0%bf%e7%97%85%e5%90%88%e5%b9%b6%e8%84%91%e6%a2%97%e6%ad%bb%e4%b8%ad%e7%9a%84%e4%bb%b7%e5%80%bc&scode=GAYX201124031' target="_blank">9</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>106</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVOB1VBBndOBFT4Z0b3gjVnNTdttySuFndjxENjZFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dGAYX201124031' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="GAYX201124031"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=13 name=CookieName  value="CJFD2011!GYKX201124128!13!0"  onclick="$(this).filenameClick()"  >13</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=13&recid=&FileName=GYKX201124128&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'><font class=Mark>糖尿病</font>患者眼底检查的时间与病情状况相关性的调查</a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      </td>
#       <td class="author">
#
#       高秀云;杨艳
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=GYKX'>China Medicine and Pharmacy</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e7%b3%96%e5%b0%bf%e7%97%85%e6%82%a3%e8%80%85%e7%9c%bc%e5%ba%95%e6%a3%80%e6%9f%a5%e7%9a%84%e6%97%b6%e9%97%b4%e4%b8%8e%e7%97%85%e6%83%85%e7%8a%b6%e5%86%b5%e7%9b%b8%e5%85%b3%e6%80%a7%e7%9a%84%e8%b0%83%e6%9f%a5&scode=GYKX201124128' target="_blank">3</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>55</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWV4kFSPd2LLVXYFBjcslWRxNWTYBXTuFndjxENjZFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dGYKX201124128' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="GYKX201124128"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=14 name=CookieName  value="CJFD2011!DDYI201136102!14!0"  onclick="$(this).filenameClick()"  >14</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=14&recid=&FileName=DDYI201136102&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'>前列地尔联合缬沙坦治疗早期<font class=Mark>糖尿病</font>肾病临床观察</a>
#
#
#
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       钟春梅;李正良;廖常冰
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=DDYI'>Contemporary Medicine</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e5%89%8d%e5%88%97%e5%9c%b0%e5%b0%94%e8%81%94%e5%90%88%e7%bc%ac%e6%b2%99%e5%9d%a6%e6%b2%bb%e7%96%97%e6%97%a9%e6%9c%9f%e7%b3%96%e5%b0%bf%e7%97%85%e8%82%be%e7%97%85%e4%b8%b4%e5%ba%8a%e8%a7%82%e5%af%9f&scode=DDYI201136102' target="_blank">28</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>477</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVxQDbBhGMN5WaoJXVVBndsJXYzJ2L3plc4IDetVFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dDDYI201136102' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="DDYI201136102"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=15 name=CookieName  value="CJFD2011!JFHL201124011!15!0"  onclick="$(this).filenameClick()"  >15</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=15&recid=&FileName=JFHL201124011&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'>Correlations between Empowerment Ability and Self-care Behaviors in Diabetics</a>
#
#
#
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       XU Mei-yue,ZHOU Juan-hua,LIN Ling-ping,ZHENG He-xin(Department of Endocrinology Zhejiang Hospital,Hangzhou 310012,China)
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=JFHL'>Nursing Journal of Chinese People's Liberation Army</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=Correlations+between+Empowerment+Ability+and+Self-care+Behaviors+in+Diabetics&scode=JFHL201124011' target="_blank">19</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>305</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVVpFeKh0SEdjdrpGZpN2bOFXMvZTdiFndjxENjZFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dJFHL201124011' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="JFHL201124011"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=16 name=CookieName  value="CJFD2011!KJXX201136026!16!0"  onclick="$(this).filenameClick()"  >16</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=16&recid=&FileName=KJXX201136026&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'>基于电子健康档案的<font class=Mark>糖尿病</font>管理模式探索</a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      </td>
#       <td class="author">
#
#       凌利峰;董建成;耿兴云;张远鹏;陈亚兰
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=KJXX'>Science & Technology Information</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>217</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVLRmWpBXdmVERwIkREhTSwR3Kwp0Uqp1UrEEV0IDbsNFcap2LzYFNBllazhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dKJXX201136026' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="KJXX201136026"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=17 name=CookieName  value="CJFD2011!ZJZY201104009!17!0"  onclick="$(this).filenameClick()"  >17</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=17&recid=&FileName=ZJZY201104009&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'>Investigation and analysis about the foot nursing knowledge and conduct of the diabetics</a>
#
#
#
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       Tian Xin,DONG Wen-xia.Department of Traditional Chinese Medicine,Air Force General Hospital,Beijing 100142,China
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=ZJZY'>Medical Journal of Air Force</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-25
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=Investigation+and+analysis+about+the+foot+nursing+knowledge+and+conduct+of+the+diabetics&scode=ZJZY201104009' target="_blank">4</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>146</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVzp2U0MjW6l1QZJXe4EHNJJkZIdneycDZpBDcVN2YwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dZJZY201104009' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="ZJZY201104009"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=18 name=CookieName  value="CJFD2011!FSJX201124031!18!0"  onclick="$(this).filenameClick()"  >18</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=18&recid=&FileName=FSJX201124031&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'><font class=Mark>糖尿病</font>患者健康教育路径与依从性探讨</a>
#
#
#
#
#
#
#
#
#
#
#            <span class="markOricon" title-hidde="Chinese Full Text">Chinese Full Text</span>
#
#
#
#      </td>
#       <td class="author">
#
#       李迅
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=FSJX'>Journal of Nurses Training</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-22
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e7%b3%96%e5%b0%bf%e7%97%85%e6%82%a3%e8%80%85%e5%81%a5%e5%ba%b7%e6%95%99%e8%82%b2%e8%b7%af%e5%be%84%e4%b8%8e%e4%be%9d%e4%bb%8e%e6%80%a7%e6%8e%a2%e8%ae%a8&scode=FSJX201124031' target="_blank">61</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>2129</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVT9CdJR2SNtCbTNEUnVmeI9kb3RWSDZDMFNDetVFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dFSJX201124031' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="FSJX201124031"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr  class="odd" >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=19 name=CookieName  value="CJFD2011!AHLC201112067!19!0"  onclick="$(this).filenameClick()"  >19</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=19&recid=&FileName=AHLC201112067&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'><font class=Mark>糖尿病</font>并发脑梗死中医诊治进展</a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      </td>
#       <td class="author">
#
#       王艳昕;蔡永亮;许珍晶
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=AHLC'>Clinical Journal of Traditional Chinese Medicine</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-20
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e7%b3%96%e5%b0%bf%e7%97%85%e5%b9%b6%e5%8f%91%e8%84%91%e6%a2%97%e6%ad%bb%e4%b8%ad%e5%8c%bb%e8%af%8a%e6%b2%bb%e8%bf%9b%e5%b1%95&scode=AHLC201112067' target="_blank">5</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>153</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWVTRlSV9GcNZmRVJ2LuRVYplVcKNkQyg1T5MjY4MFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-read"  target="online_open" href='/kns/Detail/Read?domain=tablename%3dCJFD2011%26filename%3dAHLC201112067%26dbCode%3dCJFD' title="Read online"><i></i></a>
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="AHLC201112067"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr><tr >
# <td class="seq"><input class="cbItem" type=checkbox data-cur=20 name=CookieName  value="CJFD2011!ZHER201104007!20!0"  onclick="$(this).filenameClick()"  >20</td>
#       <td class="name" >
#
#        <a class="fz14" href='/kns/Detail?sfield=fn&QueryID=0&CurRec=20&recid=&FileName=ZHER201104007&DbName=CJFD2011&DbCode=CJFD&yx=&pr=&URLID=' target='_blank'><font class=Mark>糖尿病</font>患者平衡功能障碍的发生机制</a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      </td>
#       <td class="author">
#
#       周芸;刘博
#
#       </td>
#       <td class="source">
#
#       <a  target=_blank href='/kns/Navi?DBCode=CJFD&BaseID=ZHER'>Chinese Journal of Otology</a>
#
#
#       </td>
#       <td class="date">
#         2011-12-16
#       </td>
#       <td class="data">
#         Journals
#       </td>
#       <td class="quote">
#
#          <span><a class="KnowledgeNetLink" href='/kns/Detail?sdb=CJFD&sfield=cite&skey=%e7%b3%96%e5%b0%bf%e7%97%85%e6%82%a3%e8%80%85%e5%b9%b3%e8%a1%a1%e5%8a%9f%e8%83%bd%e9%9a%9c%e7%a2%8d%e7%9a%84%e5%8f%91%e7%94%9f%e6%9c%ba%e5%88%b6&scode=ZHER201104007' target="_blank">7</a></span>
#
#       </td>
#       <td class="download">
#
#         <a class="downloadCnt" href='javascript:void(0);'>245</a>
#
#       </td>
#       <td class="operat">
#
#        <a href="/kns/download?filename=kdXcYx0VupGZ4lFVwJDeihVYJV3UElVWoFzLFtibCd2UTdXdr8yQ0UDaS5EZtV1M4N1KYplakpmWtxWV3kDevwUaOdUWmZVShFVNVVHRrEHULJVO6RENjZFZwtyT1pWMlJkY2Z3RzhkWopFNyRETR9Gc6FXdGBDb&tablename=CJFD2011" title="login and download" target=_blank class="downloadlink icon-notlogged"><i></i>download</a>
#
#
#
#
#          <a class="icon-html"  target="online_open" href='/kns/Detail/Read?flag=html&domain=dbcode%3dCJFD%26filename%3dZHER201104007' title="HTML Reading"><i></i></a>
#
#
#
#
#        <a class="icon-collect" title="Favorite" data-dbname="CJFD" data-filename="ZHER201104007"><i></i></a>
#
#
#        <a class="icon-quote" title="Citation" href="javascript:void(0)"><i></i></a>
#
#       </td>
#
#       </tr></table></td></tr></table><div class='pages'><span class='cur'>1</span><a href="javascript:void(0);" data-curpage="2" title="“← →” Turn Page" id="page2">2</a><a href="javascript:void(0);" data-curpage="3" title="“← →” Turn Page" id="page3">3</a><a href="javascript:void(0);" data-curpage="4" title="“← →” Turn Page" id="page4">4</a><a href="javascript:void(0);" data-curpage="5" title="“← →” Turn Page" id="page5">5</a><a href="javascript:void(0);" data-curpage="6" title="“← →” Turn Page" id="page6">6</a><a href="javascript:void(0);" data-curpage="7" title="“← →” Turn Page" id="page7">7</a><a href="javascript:void(0);" data-curpage="8" title="“← →” Turn Page" id="page8">8</a><a href="javascript:void(0);" data-curpage="9" title="“← →” Turn Page" id="page9">9</a><a href="javascript:void(0);" data-curpage="2" title="“← →” Turn Page" id="PageNext">Next </a></div></div>
#     </div>
#     <input id="errorMsgHid" type="hidden" value="" />
#     <input id="HandlerIdHid" type="hidden" value="0" />
#     <input id="curPageHid" type="hidden" value="1" />
#     <input id="isSortHid" type="hidden" value="false" />
#     <input id="sqlVal" type="hidden" value="..." />
#     <input id="pathAnalysisHid" type="hidden" value="https://oversea.cnki.net/kvisual/ArticleAnalysis/index?language=EN" />
#
# </form>
#
# <script type="text/javascript">
#     $(function () {
#         if ('True'=='False') {
#             $("#batchOpsBox .bulkdownload").css("display","none");
#         }
#     });
#
# </script>
# <input id="hidCurrentUserName" name="hidCurrentUserName" type="hidden" value="" />
# <input id="hidVipList" name="hidVipList" type="hidden" value="CUHK,POLYU,CITYU,HKMU,HK_SYU,UMAC,MUSTMO,MPU,CITYUMOLIB,HKUBJ,HKUST,LINGNAN,OSNSZLS,HKBU,EDUHK,HKAPA,HKCCL2007,HKDH,GATEST1,GATEST2,GATEST3,GATEST4,GATEST5,GATEST6,GATEST7,ALGOV,DSAJMO" />
# <input id="hidIsOverseaWhitePn" name="hidIsOverseaWhitePn" type="hidden" value="0" />

# %%
import httpx
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs, urlencode

def simplify_url(original_url):
    # 解析原始URL
    parsed_url = urlparse(original_url)
    query_params = parse_qs(parsed_url.query)

    # 提取所需的参数，注意大小写
    required_params = {}
    if 'dbcode' in query_params:
        required_params['dbcode'] = query_params['dbcode']
    if 'DbCode' in query_params:
        required_params['DbCode'] = query_params['DbCode']
    if 'filename' in query_params:
        required_params['filename'] = query_params['filename']
    if 'FileName' in query_params:
        required_params['FileName'] = query_params['FileName']

    # 重新构建URL
    simplified_url = f"https://www.cnki.net/KCMS/detail/detail.aspx?{urlencode(required_params, doseq=True)}"
    return simplified_url

def get_ab_key(url):
    content_ab = httpx.get('https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=XHYX20240523001', ).text
    soup = BeautifulSoup(content_ab, 'html.parser')
    
    # 提取摘要
    abstract = soup.find('span', {'id': 'ChDivSummary'}).get_text(strip=True)
    
    # 提取关键词
    keywords = soup.find('p', {'class': 'keywords'}).get_text(separator='; ', strip=True)
    return abstract, keywords



# 设置请求头
headers = {
    "Accept": "text/html, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Cookie": "eng_k55_id=015106; Ecp_ClientId=n240530105000408699; firstEnterUrlInSession=https%3A//www.cnki.net/index/; Ecp_IpLoginFail=240530167.220.232.161; VisitorCapacity=1; ASP.NET_SessionId=eo1ucf3cp2lx30ttvijeph52; pageReferrInSession=https%3A//www.cnki.net/index/; knsLeftGroupSelectItem=1%3B2%3B; CurrSortField=Relevance%2frelevant%2c(%e5%8f%91%e8%a1%a8%e6%97%b6%e9%97%b4%2c%27time%27)+desc; CurrSortFieldType=desc; Ecp_ClientIp=-1; dblang=ch; tfstk=f4ZmC-M8drubS19Oiumf4HiO2q_-lIisa5Kt6chNzblWMIKYQf4ggS0ZWtGTZ1VuCjrOhOiMb7wEBrhxHODZaS0TXtt9hzNLLnEAlcKicciN96IdvKwjfcSPmxoEG8ySQr9Hzw2bhc95FbXqq-Tg8IBFncPZ43ksQckqghWkavGy0A-qQQWoCblZbq-aULknQCkZ3jLpbXqaVuWpyoS_UzZYqx0PJ-lyRjronqcU3oxwbdMmoXyqZ6pGT90zCVq6Ch0L3yNsLSRVsfZuUozUT_LxgyDgpPVhYhM7uSqrSuB1x8nmI2oZrd-aE0lZ-onFYQD7z-UacSvMbxZYvVcIrO-sW0rK8yPDC9wr0APsRlCBcjyadkaKxiAInzynqgyXzellIhMPBu865qkSEX1XSyvkPZ-3UTXkRZgqFxCdETY65qkSEXBlEeOjuYMA9",
    "Host": "www.cnki.net",
    "Origin": "https://www.cnki.net",
    "Referer": "https://www.cnki.net/kns/defaultresult/index",
    "Sec-Ch-Ua": '"Chromium";v="124", "Microsoft Edge";v="124", "Not-A.Brand";v="99"',
    "Sec-Ch-Ua-Mobile": "?0",
    "Sec-Ch-Ua-Platform": '"Windows"',
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
    "X-Requested-With": "XMLHttpRequest"
}

# 设置请求 payload
payload = {
    "IsSearch": True,
    "QueryJson": "{\"Platform\":\"\",\"DBCode\":\"CFLS\",\"KuaKuCode\":\"CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFN\",\"QNode\":{\"QGroup\":[{\"Key\":\"Subject\",\"Title\":\"\",\"Logic\":1,\"Items\":[{\"Title\":\"Subject\",\"Name\":\"SU\",\"Value\":\"糖尿病\",\"Operate\":\"%\",\"BlurType\":\"\"}],\"ChildItems\":[]}]},\"CodeLang\":\"ch\"}",
    "PageName": "defaultresult",
    "DBCode": "CFLS",
    "KuaKuCodes": "CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFN",
    "CurPage": 2,
    "RecordsCntPerPage": 20,
    "CurDisplayMode": "listmode",
    "CurrSortField": "",
    "CurrSortFieldType": "desc",
    "IsSentenceSearch": False,
    "Subject": ""
}

# 将payload转换为URL编码的字符串
encoded_payload = urlencode(payload)

# 发送POST请求
response = httpx.post('https://www.cnki.net/kns/Brief/GetGridTableHtml', headers=headers, data=encoded_payload)
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Extract data from the table
data = []
rows = soup.find("table", class_="result-table-list").find_all('tr')
for row in rows:
    title_tag = row.find('td', class_='name')
    if not title_tag:
        continue
    title = title_tag.find('a').text.strip()
    url = simplify_url(title_tag.find('a')['href'])
    author = row.find('td', class_='author').text.strip()
    source = row.find('td', class_='source').text.strip()
    date = row.find('td', class_='date').text.strip()
    data_type = row.find('td', class_='data').text.strip()
    quote = row.find('td', class_='quote').text.strip()
    keywords = ""
    abstract = ""
    
    data.append({
        'Title': title,
        'URL': url,
        'Author': author,
        'Source': source,
        'Date': date,
        'Database': data_type,
        'Quote': quote,
        'Keywords': keywords,
        'Abstract': abstract
    })

# Create a DataFrame and save as CSV
df = pd.DataFrame(data)
df.to_csv('papers(new).csv', index=False)
data
# Out:
# [{'Title': 'Guideline for the Management of Diabetes Mellitus in the Elderly in China (2024 edition)',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=XHYX20240523001',
#   'Author': 'National Center of Gerontology;Chinese Society of Geriatrics;Diabetes Professional Committee of Chinese Aging Well Association;GUO Lixin;XIAO Xinhua',
#   'Source': 'Medical Journal of Peking Union Medical College Hospital',
#   'Date': '2024-05-28 15:22',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Diabetes burden in China from 1999 to 2019',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=JFJY20240515001',
#   'Author': 'Li Zan;Liu Xi-Yang;He Zhuo-Jia;Ma Shuang',
#   'Source': "Medical Journal of Chinese People's Liberation Army",
#   'Date': '2024-05-21 14:42',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Discussion on the treatment for Diabetes Mellitus with modification of Guizhi Decoction',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=LZXB2024041900A',
#   'Author': 'WAN Haiping;GONG Xuan;CAI Haobin;CAI Tiantian;LIN Songjun',
#   'Source': 'Journal of Liaoning University of Traditional Chinese Medicine',
#   'Date': '2024-05-13 15:00',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Treatment of diabetic kidney disease from the spleen based on the theory of "spleen circulation and transfusion balance”',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=LNZY20240430001',
#   'Author': 'Zhou Cheng;Yang Yu-feng;An Ji-ren;Sun Gui-yan;Guan Ming-dan;Yu Jia-xiang;Shi Yan',
#   'Source': 'Liaoning Journal of Traditional Chinese Medicine',
#   'Date': '2024-04-30 16:29',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Risk Factors,Prognosis and Rapid Screening in Patients with Acute Aortic Dissection Complicated with Type 2 Diabetes',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=QKYX20240408001',
#   'Author': 'HUANG Lujie;ZHANG Xiaoying;YU Shasha',
#   'Source': 'Chinese General Practice',
#   'Date': '2024-04-11 16:22',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Research Progress of Traditional Chinese Medicine Treatment for Diabetes and Its Complications：A Review',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=ZSFX20240314001',
#   'Author': 'CAI Rushuang;YI Yan',
#   'Source': 'Chinese Journal of Experimental Traditional Medical Formulae',
#   'Date': '2024-03-19 11:02',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Progress in Animal Models of Type 2 Diabetes with Disease-Zheng(证) Combination',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=ZYYL20230911002',
#   'Author': 'GU Jiaqi;QIN Lilan;XU Qiang',
#   'Source': 'Pharmacology and Clinics of Chinese Materia Medica',
#   'Date': '2023-09-13 16:01',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Studies on pathophysiological characteristics of mice with diabetes combined with SARS-CoV-2 Spike protein infection',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=YLBS20230527001',
#   'Author': 'SU Xiao-yue;LI Jing-xuan;LIN Ying;ZHANG Yong-xiang;XIAO Zhi-yong;ZHOU Wen-xia',
#   'Source': 'Chinese Journal of Pharmacology and Toxicology',
#   'Date': '2023-05-30 10:08',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Clinical features of bacterial liver abscess with diabetes',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CAPJ&FileName=ZPWL20200923004',
#   'Author': 'GUO Mingfeng;ZHOU Bing',
#   'Source': 'Chinese Journal of Bases and Clinics in General Surgery',
#   'Date': '2020-09-24 09:05',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '糖尿病患者骨密度变化的相关因素分析',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=ZGSQ201136121',
#   'Author': '王希武',
#   'Source': 'Chinese Community Doctors',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '4',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '中西医结合治疗糖尿病膀胱的效果',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=DDYI201136114',
#   'Author': '林连辉',
#   'Source': 'Contemporary Medicine',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '6',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '同型半胱氨酸和超敏C反应蛋白检测在糖尿病合并脑梗死中的价值',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=GAYX201124031',
#   'Author': '叶润清;吴晓蔓',
#   'Source': 'Guangdong Medical Journal',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '9',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '糖尿病患者眼底检查的时间与病情状况相关性的调查',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=GYKX201124128',
#   'Author': '高秀云;杨艳',
#   'Source': 'China Medicine and Pharmacy',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '3',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '前列地尔联合缬沙坦治疗早期糖尿病肾病临床观察',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=DDYI201136102',
#   'Author': '钟春梅;李正良;廖常冰',
#   'Source': 'Contemporary Medicine',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '28',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Correlations between Empowerment Ability and Self-care Behaviors in Diabetics',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=JFHL201124011',
#   'Author': 'XU Mei-yue,ZHOU Juan-hua,LIN Ling-ping,ZHENG He-xin(Department of Endocrinology Zhejiang Hospital,Hangzhou 310012,China)',
#   'Source': "Nursing Journal of Chinese People's Liberation Army",
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '19',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '基于电子健康档案的糖尿病管理模式探索',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=KJXX201136026',
#   'Author': '凌利峰;董建成;耿兴云;张远鹏;陈亚兰',
#   'Source': 'Science & Technology Information',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': 'Investigation and analysis about the foot nursing knowledge and conduct of the diabetics',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=ZJZY201104009',
#   'Author': 'Tian Xin,DONG Wen-xia.Department of Traditional Chinese Medicine,Air Force General Hospital,Beijing 100142,China',
#   'Source': 'Medical Journal of Air Force',
#   'Date': '2011-12-25',
#   'Database': 'Journals',
#   'Quote': '4',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '糖尿病患者健康教育路径与依从性探讨',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=FSJX201124031',
#   'Author': '李迅',
#   'Source': 'Journal of Nurses Training',
#   'Date': '2011-12-22',
#   'Database': 'Journals',
#   'Quote': '61',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '糖尿病并发脑梗死中医诊治进展',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=AHLC201112067',
#   'Author': '王艳昕;蔡永亮;许珍晶',
#   'Source': 'Clinical Journal of Traditional Chinese Medicine',
#   'Date': '2011-12-20',
#   'Database': 'Journals',
#   'Quote': '5',
#   'Keywords': '',
#   'Abstract': ''},
#  {'Title': '糖尿病患者平衡功能障碍的发生机制',
#   'URL': 'https://www.cnki.net/KCMS/detail/detail.aspx?DbCode=CJFD&FileName=ZHER201104007',
#   'Author': '周芸;刘博',
#   'Source': 'Chinese Journal of Otology',
#   'Date': '2011-12-16',
#   'Database': 'Journals',
#   'Quote': '7',
#   'Keywords': '',
#   'Abstract': ''}]

# %%
import httpx
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs, urlencode

def simplify_url(original_url):
    # 解析原始URL
    parsed_url = urlparse(original_url)
    query_params = parse_qs(parsed_url.query)

    # 提取所需的参数，注意大小写
    required_params = {}
    for key in ['dbcode', 'DbCode', 'filename', 'FileName']:
        if key in query_params:
            required_params[key.lower()] = query_params[key][0]

    # 重新构建URL
    simplified_url = f"https://www.cnki.net/KCMS/detail/detail.aspx?{urlencode(required_params, doseq=True)}"
    return simplified_url

def get_ab_key(url):
    # 发送GET请求并解析页面内容
    response = httpx.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # 提取摘要
    abstract_tag = soup.find('span', {'id': 'ChDivSummary'})
    abstract = abstract_tag.get_text(strip=True) if abstract_tag else ""

    # 提取关键词
    keywords_tag = soup.find('p', {'class': 'keywords'})
    keywords = keywords_tag.get_text(separator='; ', strip=True) if keywords_tag else ""

    return abstract, keywords

# 设置请求头
headers = {
    "Accept": "text/html, */*; q=0.01",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Host": "www.cnki.net",
    "Origin": "https://www.cnki.net",
    "Referer": "https://www.cnki.net/kns/defaultresult/index",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0",
    "X-Requested-With": "XMLHttpRequest"
}

# 设置请求 payload
payload = {
    "IsSearch": False,
    "QueryJson": "{\"Platform\":\"\",\"DBCode\":\"CFLS\",\"KuaKuCode\":\"CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFN\",\"QNode\":{\"QGroup\":[{\"Key\":\"Subject\",\"Title\":\"\",\"Logic\":1,\"Items\":[{\"Title\":\"Subject\",\"Name\":\"SU\",\"Value\":\"慢性淋巴细胞甲状腺炎\",\"Operate\":\"%\",\"BlurType\":\"\"}],\"ChildItems\":[]}]},\"CodeLang\":\"ch\"}",
    "PageName": "defaultresult",
    "DBCode": "CFLS",
    "KuaKuCodes": "CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFQ,CDMD,CIPD,CCND,CYFD,CCJD,BDZK,CISD,CJFN",
    "CurPage": 8,
    "RecordsCntPerPage": 50,
    "CurDisplayMode": "listmode",
    "CurrSortField": "",
    "CurrSortFieldType": "desc",
    "IsSentenceSearch": False,
    "Subject": ""
}

def get_df(page=1):
    # 将payload转换为URL编码的字符串
    payload['CurPage'] = page
    encoded_payload = urlencode(payload)
    
    # 发送POST请求
    response = httpx.post('https://www.cnki.net/kns/Brief/GetGridTableHtml', headers=headers, data=encoded_payload)
    
    # 使用BeautifulSoup解析HTML内容
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # 从表格中提取数据
    data = []
    rows = soup.find("table", class_="result-table-list").find_all('tr')
    for row in rows:
        title_tag = row.find('td', class_='name')
        if not title_tag:
            continue
        title = title_tag.find('a').text.strip()
        url = simplify_url(title_tag.find('a')['href'])
        author = row.find('td', class_='author').text.strip()
        source = row.find('td', class_='source').text.strip()
        date = row.find('td', class_='date').text.strip()
        data_type = row.find('td', class_='data').text.strip()
        quote = row.find('td', class_='quote').text.strip()
    
        # 获取摘要和关键词
        abstract, keywords = get_ab_key(url)
        
        data.append({
            'Title': title,
            'URL': url,
            'Author': author,
            'Source': source,
            'Date': date,
            'Database': data_type,
            'Quote': quote,
            'Keywords': keywords,
            'Abstract': abstract
        })

    return pd.DataFrame(data)

df_list = []
for i in range(1, 9):
    df_list.append(get_df(i))
    print(i, end='_')

combined_df = pd.concat(df_list, ignore_index=True)
# 创建DataFrame并保存为CSV文件，使用utf-8-sig编码以避免Excel打开时中文乱码
CurPage = int(payload['CurPage'])
RecordsCntPerPage = int(payload['RecordsCntPerPage'])
file_path = 'papers(whole).csv'

combined_df.to_csv(file_path, index= False, encoding= 'utf-8-sig')
combined_df
# Out:
# 1_2_3_4_5_6_7_8_
#                                                  Title  \
# 0    Study on Chronic Lymphocytic Thyroiditis from ...
# 1                              慢性淋巴细胞性甲状腺炎外科治疗(附49例分析)
# 2    Role of cytokine imbalance mediated by nitric ...
# 3                                     慢性淋巴细胞性甲状腺炎的临床特点
# 4    The effect of rhIL  10 on the imbalance of IFN...
# ..                                                 ...
# 377                                          抗体药物研究与应用
# 378                                        医学影像学读片诊断图谱
# 379                                       内科常见疾病药物治疗手册
# 380                                               甲状腺学
# 381                               慢性淋巴细胞性甲状腺炎的局部免疫调节治疗
#
#                                                    URL  \
# 0    https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 1    https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 2    https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 3    https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 4    https://www.cnki.net/KCMS/detail/detail.aspx?d...
# ..                                                 ...
# 377      https://www.cnki.net/KCMS/detail/detail.aspx?
# 378      https://www.cnki.net/KCMS/detail/detail.aspx?
# 379      https://www.cnki.net/KCMS/detail/detail.aspx?
# 380      https://www.cnki.net/KCMS/detail/detail.aspx?
# 381  https://www.cnki.net/KCMS/detail/detail.aspx?d...
#
#                                                 Author  \
# 0                                 LI Haoming;ZHANG Lan
# 1                                      李文岗,丁田贵,孙毅群,张德恒
# 2    DONG Wen  bin,RAN Long  rui,XIAO Da  chengDepa...
# 3                                                  王深明
# 4    DONG Wenbin, XIAO Dacheng, RAN Longrui, et al....
# ..                                                 ...
# 377                                邵荣光，甄永苏 主编；张胜华 主编助理
# 378                             丁建平，王霄英 总主编；耿左军，杨本涛 主编
# 379                                          郭涛，史国兵 主编
# 380                                         滕卫平，单忠艳 主编
# 381                                                王龙安
#
#                                                 Source              Date  \
# 0    Journal of Practical Traditional Chinese Inter...  2023-11-02 10:52
# 1    JOURNAL OF NORMAN BETHUNE UNIVERSITY OF MEDICA...        2000-07-30
# 2         JOURNAL OF CELLULAR AND MOLECULAR IMMUNOLOGY        2000-02-29
# 3                 CHINESE JOURNAL OF PRACTICAL SURGERY        2000-02-25
# 4                        Chinexe Journal of Pediatrics        2000-02-16
# ..                                                 ...               ...
# 377                                                               201309
# 378                                                               201309
# 379                                                               201603
# 380                                                               202106
# 381                                Health for Everyone        2017-07-23
#
#      Database Quote                                           Keywords  \
# 0    Journals        Yin fire theory;; chronic lymphocytic thyroidi...
# 1    Journals     1                      慢性淋巴细胞性甲状腺炎;; 外科治疗;; 甲状腺自身抗体;
# 2    Journals     4  thyoiditis;; autoimmunity;; nitric oxide;; IFN...
# 3    Journals    27
# 4    Journals    13  Thyroiditis, autoimmune;; Interleukin  10;; In...
# ..        ...   ...                                                ...
# 377               7
# 378               1
# 379
# 380               9
# 381  Journals                            慢性淋巴细胞性甲状腺炎;; 局部免疫调节;; 糖皮质激素;
#
#                                               Abstract
# 0    Based on Li Dongyuan’s Yin fire theory， this p...
# 1    目的 :研究手术加药物治疗对慢性淋巴细胞性甲状腺炎 （ CLT）的临床意义。方法 :对 4年...
# 2    Aim    To probe the role of serum nitric oxide...
# 3
# 4    Objective  To explore the effect of IL  10 on ...
# ..                                                 ...
# 377
# 378
# 379
# 380
# 381  目的:探讨慢性淋巴细胞性甲状腺炎的局部免疫调节治疗。方法:选取我院2015年6月至2017年...
#
# [382 rows x 9 columns]

# %%
combined_df = pd.concat([df, df], ignore_index=True)
combined_df
# Out:
#                                                 Title  \
# 0   Clinical Observation of Buzhongyiqi Decoction ...
# 1                                    慢性淋巴细胞性甲状腺炎的治疗进展
# 2                      甲状腺激素抵抗综合征合并慢性淋巴细胞性甲状腺炎1例并文献复习
# 3                                慢性淋巴细胞性甲状腺炎的超声诊断价值影响
# 4                              应用含碘中药治疗慢性淋巴细胞性甲状腺炎的探讨
# ..                                                ...
# 59                                          抗体药物研究与应用
# 60                                        医学影像学读片诊断图谱
# 61                                       内科常见疾病药物治疗手册
# 62                                               甲状腺学
# 63                               慢性淋巴细胞性甲状腺炎的局部免疫调节治疗
#
#                                                   URL  \
# 0   https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 1   https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 2   https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 3   https://www.cnki.net/KCMS/detail/detail.aspx?d...
# 4   https://www.cnki.net/KCMS/detail/detail.aspx?d...
# ..                                                ...
# 59      https://www.cnki.net/KCMS/detail/detail.aspx?
# 60      https://www.cnki.net/KCMS/detail/detail.aspx?
# 61      https://www.cnki.net/KCMS/detail/detail.aspx?
# 62      https://www.cnki.net/KCMS/detail/detail.aspx?
# 63  https://www.cnki.net/KCMS/detail/detail.aspx?d...
#
#                       Author                                      Source  \
# 0                        韦利英  Chinese Master's Theses Full-text Database
# 1                        单忠艳                      中华医学会第十次全国内分泌学学术会议论文汇编
# 2   卢琳;连小兰;苏浩;张妲;戴为信;夏维波;邢小平                      中华医学会第十次全国内分泌学学术会议论文汇编
# 3                 秦丽微;郑春梅;曹霞               中国超声医学工程学会第九届全国腹部超声医学学术会议论文汇编
# 4                      张兰;张颖               5TH全国中西医结合内分泌代谢病学术大会暨糖尿病论坛论文集
# ..                       ...                                         ...
# 59       邵荣光，甄永苏 主编；张胜华 主编助理
# 60    丁建平，王霄英 总主编；耿左军，杨本涛 主编
# 61                 郭涛，史国兵 主编
# 62                滕卫平，单忠艳 主编
# 63                       王龙安                         Health for Everyone
#
#           Date           Database Quote Keywords Abstract
# 0   2023-03-01    Master's Theses
# 1   2011-08-17  China Conferences
# 2   2011-08-17  China Conferences
# 3   2012-08-01  China Conferences
# 4   2012-11-02  China Conferences     2
# ..         ...                ...   ...      ...      ...
# 59      201309                        7
# 60      201309                        1
# 61      201603
# 62      202106                        9
# 63  2017-07-23           Journals
#
# [64 rows x 9 columns]

# %%
abstract
# Out:
# 'With the aging of China， the prevalence of diabetes mellitus in the elderly has significantly increased， highlighting the importance of its standardized management in improving the clinical outcomes of elderly diabetic patients. In 2021， the National Center of Gerontology， Chinese Society of Geriatrics， Diabetes Professional Committee of Chinese Aging Well Association organized experts to write China’s first guideline for diabetes mellitus in the elderly， namely “Guideline for the Management of Diabetes Mellitus in the Elderly in China （2021 edition）”. The Guideline emphasized the high heterogeneity of elderly diabetic patients， the need for comprehensive assessment， the adoption of stratified and individualized management strategies， and for the first time proposed the "simple treatment concept" and "de-intensified treatment strategy" for elderly diabetic patients. This guideline， providing clinicians with practical and operable clinical guidance， has not only promoted the standardized comprehensive management of elderly diabetic patients in China in all aspects and cycles， but also promoted the extensive development of clinical and basic research on elderly diabetes mellitus and related fields in China. In the past three years since the release of the guideline， evidence of evidence-based medicine in geriatric diabetes and related fields at home and abroad has been further accumulated， and new treatment concepts， new types of drugs and therapeutic technologies have emerged. The editorial committee of the guideline has updated the first edition of the guideline， further refined and optimized the pathway of glycemic management of geriatric diabetes， and compiled the " Guideline for the Management of Diabetes Mellitus in the Elderly in China （2024 edition）"， with the hope of continuing to help standardize the management of Chinese elderly diabetes patients and improve their clinical outcomes.'

# %%
keywords
# Out:
# 'diabetes mellitus;; aged;; guidebooks;; treatment pathways;'

# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# 读取CSV文件
file_path = 'papers(whole).csv'
df = pd.read_csv(file_path)

# 提取关键词列并统计频率
keywords = df['Keywords'].dropna().str.replace(';', '').str.split()
all_keywords = [keyword for sublist in keywords for keyword in sublist]
keyword_counts = Counter(all_keywords)

# 上传字体文件后，指定字体路径
uploaded_font_path = r'C:\Windows\Fonts\simfang.ttf'

# 生成词云图
wordcloud = WordCloud(width=800, height=400, background_color='white', font_path=uploaded_font_path).generate_from_frequencies(keyword_counts)

# 显示词云图
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig('papers.png')
plt.show()

# %%
keywords
# Out:
# 0      [Yin, fire, theory, chronic, lymphocytic, thyr...
# 1                           [慢性淋巴细胞性甲状腺炎, 外科治疗, 甲状腺自身抗体]
# 2      [thyoiditis, autoimmunity, nitric, oxide, IFN,...
# 4      [Thyroiditis,, autoimmune, Interleukin, 10, In...
# 6      [thyroiditis, Tripterygium, Witfondii, Hooh, F...
#                              ...
# 350    [Buzhong, Yiqi, decoction, Chronic, lymphocyti...
# 353                            [慢性淋巴细胞性甲状腺炎, 超声诊断, 影像特征]
# 358                [慢性淋巴细胞性甲状腺炎, 细针吸取细胞学, 甲状腺功能, 抗甲状腺抗体]
# 363                                     [桥本甲状腺炎, 碘剂, 造模]
# 381                         [慢性淋巴细胞性甲状腺炎, 局部免疫调节, 糖皮质激素]
# Name: Keywords, Length: 241, dtype: object

# %%
import pandas as pd

# 读取CSV文件
file_path = 'papers(whole).csv'
df = pd.read_csv(file_path)

# 替换 Keywords 列中的 `;;` 为 `;`
df['Keywords'] = df['Keywords'].str.replace(';;', ';')

# 按 Quote 列的数量排序
df_sorted = df.sort_values(by='Quote', ascending=False)

# 保存处理后的CSV文件
output_file_path = 'papers_processed.csv'
df_sorted.to_csv(output_file_path, index=False, encoding='utf-8-sig')

# 显示前几行处理后的数据
df_sorted.head()
