# %% [markdown]
# ### 爬虫-IP屏蔽1/2

# %%
import requests

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0',
    'Cookie': 'Hm_lvt_020fbaad6104bcddd1db12d6b78812f6=1741592473; HMACCOUNT=51B6C851668D4097; _gid=GA1.2.1546060013.1741592474; footprints=eyJpdiI6IkRXSXpad0huZEtXMUJxblhrR0lUK0E9PSIsInZhbHVlIjoiaFFRQURreDFIaHFFTjNyditBT2pQSWtLM2s0M3VYc3ZcL0ZIeFpcLytDejBOV1VISHhBZmRpQWhpMlBIT3ZCWTNPIiwibWFjIjoiNTcwYjUxNDQ1MGMwZTUwOTlkNTc0NjEyOTI1NjRhZWU1ZDljNjgzMDI1NmUwMDI3YzMxYzIwZjZiOWZhZDg3ZCJ9; remember_web_59ba36addc2b2f9401580f014c7f58ea4e30989d=%3D; XSRF-TOKEN=eyJpdiI6IjByY1l5U3BndytSd05vaDM3Yk9OT3c9PSIsInZhbHVlIjoiMmRKUHpoVU1vZDdZQVlcL2J3VW5TUzJcL0ROSGF3cXZJaGtsZ1pSZGxQSGtBbVZcL0lNaVJkd1BOaGliSHdPQUFPNiIsIm1hYyI6IjU5NmM1OGIzYzRjODU5NDc2Y2RjNzhjYmZlMjAwYWMyYTdkNDA1ZjYyNjI1OWZmZTY5MTcwMWJjNThmZDkzYjUifQ%3D%3D; glidedsky_session=eyJpdiI6InZIK3NTNTNVdXVYSENkZGxzbWdXdHc9PSIsInZhbHVlIjoiQXZQaW9admhHMlV4blBLc3NxT0NRN0I4eE92Rkk3Zlg1VVZlR1hteEtWTE5sNmFFOFdzQmdaZWF2VEFcLzdzZzciLCJtYWMiOiI4ODkwNTQ4ZTEzNzdhMTllZmRiMDk2NGE1ZjE4NDhjOTk2ZmVhZTg4MDY3ZjEzN2NjZDUyNDk3OTkyOTZiMjg5In0%3D; _ga_YF6WY50PGC=GS1.1.1741660158.2.1.1741660204.0.0.0; _ga=GA1.2.1572004822.1741592473; Hm_lpvt_020fbaad6104bcddd1db12d6b78812f6=1741660205'
}

def get_proxies():
    proxy_username = '4c41328e'
    proxy_password = 'ab0ab20f4c744240815604198c74eac4'
    proxy = f'https://{proxy_username}:{proxy_password}@adsl.proxy.acedata.cloud:30005'

    proxies = {
        'http': proxy,
        'https': proxy
    }
    return proxies

from bs4 import BeautifulSoup
import urllib3

# 禁用 InsecureRequestWarning
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def get_page_num(page_index):
    resp = requests.get(f'http://glidedsky.com/level/web/crawler-ip-block-2?page={page_index}', proxies=proxies, headers=headers, verify=False)
    soup = BeautifulSoup(resp.text, 'html.parser')
    col = soup.select(".col-md-1")
    num_list = [int(num.text.strip()) for num in col]
    return sum(num_list)

proxies = get_proxies()
# get_page_num(2)

# %%
from tqdm import tqdm
from time import sleep

total_num = 0
num_dict = {}

for index in tqdm(range(1, 1001)):
    while True:
        try:
            page_num = 0
            while page_num == 0:
                page_num = get_page_num(index)
                sleep(0.5)
            num_dict[index] = page_num
            total_num += page_num
            break
        except Exception as e:
            sleep(5)
            continue

# %% [markdown]
# ### 爬虫-验证码-1

# %%
import time, re, json
import requests
import random
import cv2
import numpy as np
from PIL import Image
from io import BytesIO
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.service import Service

class GlidedSkySpider:
    def __init__(self):
        # 创建浏览器实例
        options = webdriver.EdgeOptions()
        options.add_extension('proxy_auth_plugin.zip')  # 添加代理扩展

        # 启动浏览器
        self.driver = webdriver.Edge() # service=Service(), options=options

    def init_page(self):
        self.open_website('http://glidedsky.com/')
        self.driver.maximize_window()
        self.load_cookie()

    def open_website(self, url):
        self.driver.get(url)
        time.sleep(2)  # 等待页面加载

    def get_captcha_images(self):
        # 切换到 iframe
        iframe_element = self.driver.find_element(By.ID, 'tcaptcha_iframe_dy')
        self.driver.switch_to.frame(iframe_element)

        # 获取背景图和滑块图
        bg_element = self.driver.find_element(By.ID, 'slideBg')
        bg_style = bg_element.get_attribute('style')
        bg_url = re.search(r'url\("(.+?)"\)', bg_style).group(1)

        # 获取滑块图
        slider_element = self.driver.find_element(By.CSS_SELECTOR, '#tcOperation > div:nth-child(8)')
        slider_style = slider_element.get_attribute('style')
        slider_url = re.search(r'url\("(.+?)"\)', slider_style).group(1)
        position = re.search(r'background-position:\s*(-?\d+\.?\d*)px\s*(-?\d+\.?\d*)px', slider_style)
        # x_offset, y_offset = float(position.group(1)), float(position.group(2))

        # 下载图片
        bg_img = Image.open(BytesIO(requests.get(bg_url).content))
        slider_img = Image.open(BytesIO(requests.get(slider_url).content))

        # 解析尺寸信息
        # width = float(re.search(r'width:\s*(\d+\.?\d*)px', slider_style).group(1))
        # height = float(re.search(r'height:\s*(\d+\.?\d*)px', slider_style).group(1))

        
        # 将图像缩小一半
        bg_small = bg_img.resize((bg_img.width // 2, bg_img.height // 2))
        slider_small = slider_img.resize((slider_img.width // 2, slider_img.height // 2))

        # 裁剪滑块部分
        slider_cropped = slider_small.crop((abs(70.8333), abs(247.917),
                                          abs(70.8333) + 60.7143, abs(247.917) + 60.7143))

        # 保存图片
        bg_small.save('img/background.png')
        slider_cropped.save('img/slider.png')

    def get_offset(self):
        # 读取图像并预处理
        background = cv2.imread('img/background.png', 0)
        slider = cv2.imread('img/slider.png', 0)

        # 图像模糊处理 (减少噪声)
        background = cv2.GaussianBlur(background, (5, 5), 0)
        slider = cv2.GaussianBlur(slider, (5, 5), 0)

        # Canny 边缘检测 (提高边缘特征)
        background = cv2.Canny(background, 100, 200)
        slider = cv2.Canny(slider, 100, 200)

        # 模板匹配
        result = cv2.matchTemplate(background, slider, cv2.TM_CCOEFF_NORMED)

        # 获取最佳匹配位置
        _, max_val, _, max_loc = cv2.minMaxLoc(result)

        # 返回滑块需要移动的距离
        return max_loc[0]

    def move_slider(self, distance):
        # 定位滑块按钮
        slider_button = self.driver.find_element(By.CSS_SELECTOR, '#tcOperation > div.tc-fg-item.tc-slider-normal')

        # 创建动作链
        action = ActionChains(self.driver)

        # 点击并按住滑块
        action.click_and_hold(slider_button).perform()

        # 模拟人类滑动轨迹
        track = self.generate_track(distance - 30)
        for x in track:
            action.move_by_offset(x, 0).perform()

        # 松开滑块
        action.release().perform()

        # 切回主页面
        self.driver.switch_to.default_content()

    def generate_track(self, distance):
        """优化滑动轨迹：加速 → 匀速 → 减速"""
        track = []
        current = 0
        mid = distance * 3 / 4  # 在3/4处开始减速
        while current < distance:
            if current < mid:
                step = random.randint(15, 20)  # 加速阶段
            else:
                step = random.randint(10, 15)  # 减速阶段
            current += step
            track.append(step)
        track[-1] -= current - distance  # 调整最后一步，使其正好到达目标位置
        return track

    def run(self, url):
        self.open_website(url)
        self.get_captcha_images()
        distance = self.get_offset()
        self.move_slider(distance)
        print("✅ 滑动验证码已完成")

    def save_cookie(self):
        # 获取当前所有cookies
        cookies = self.driver.get_cookies()

        # 将cookies保存到JSON文件
        with open('cookies.json', 'w') as file:
            json.dump(cookies, file, indent=4)  # indent参数使文件更易读

    def load_cookie(self):
        # 从JSON文件中读取Cookie
        with open('cookies.json', 'r') as file:
            cookies = json.load(file)

        # 逐个添加Cookie到浏览器
        for cookie in cookies:
            # 处理可能的expiry类型问题（JSON可能将expiry转为float）
            if "expiry" in cookie:
                cookie["expiry"] = int(cookie["expiry"])  # 转换为整数
            self.driver.add_cookie(cookie)

# %%
# 运行爬虫
spider = GlidedSkySpider()
spider.init_page()
spider.driver.get('http://glidedsky.com/level/web/crawler-captcha-1?page=1')

# %%
spider.driver.switch_to.default_content()
spider.get_captcha_images()

distance = spider.get_offset()
spider.move_slider(distance)

# %%
# 读取图像并预处理
background = cv2.imread('img/background.png', 0)
slider = cv2.imread('img/slider.png', 0)

# 图像模糊处理 (减少噪声)
background = cv2.GaussianBlur(background, (5, 5), 0)
slider = cv2.GaussianBlur(slider, (5, 5), 0)

# Canny 边缘检测 (提高边缘特征)
background = cv2.Canny(background, 100, 200)
slider = cv2.Canny(slider, 100, 200)

# 模板匹配
result = cv2.matchTemplate(background, slider, cv2.TM_CCOEFF_NORMED)

# 获取最佳匹配位置
_, max_val, _, max_loc = cv2.minMaxLoc(result)

# 返回滑块需要移动的距离
distance = max_loc[0]
distance
# Out:
# 38

# %%
cv2.minMaxLoc(result)
# Out:
# (-0.09300976246595383, 0.1980607807636261, (120, 40), (38, 106))

# %%
# 切换到 iframe
iframe_element = spider.driver.find_element(By.ID, 'tcaptcha_iframe_dy')
spider.driver.switch_to.frame(iframe_element)

def generate_track(distance):
    """优化滑动轨迹：加速 → 匀速 → 减速"""
    track = []
    current = 0
    mid = distance * 3 / 4  # 在3/4处开始减速
    while current < distance:
        if current < mid:
            step = random.randint(8, 10)  # 加速阶段
        else:
            step = random.randint(4, 6)  # 减速阶段
        current += step
        track.append(step)
    return track

# 定位滑块按钮
slider_button = spider.driver.find_element(By.CSS_SELECTOR, '#tcOperation > div.tc-fg-item.tc-slider-normal')

# 创建动作链
action = ActionChains(spider.driver)

# 点击并按住滑块
action.click_and_hold(slider_button).perform()

# 模拟人类滑动轨迹
track = generate_track(120 - 30)
for x in track:
    action.move_by_offset(x, 0).perform()

# 松开滑块
action.release().perform()

# %%
import cv2
import numpy as np

# 读取图像并预处理
background = cv2.imread('img/background.png', 0)
slider = cv2.imread('img/slider.png', 0)

# 图像模糊处理 (减少噪声)
background = cv2.GaussianBlur(background, (5, 5), 0)
slider = cv2.GaussianBlur(slider, (5, 5), 0)

# Canny 边缘检测 (提高边缘特征)
background = cv2.Canny(background, 100, 200)
slider = cv2.Canny(slider, 100, 200)

# 模板匹配
result = cv2.matchTemplate(background, slider, cv2.TM_CCOEFF_NORMED)

# 获取最佳匹配位置
_, max_val, _, max_loc = cv2.minMaxLoc(result)

# 获取滑块的宽度和高度
h, w = slider.shape

# 绘制矩形框以标记滑块缺口
marked_img = cv2.imread('img/background.png')  # 加载原始彩色图 (用于绘制)

cv2.rectangle(marked_img,                      # 图像
              max_loc,                        # 左上角坐标
              (max_loc[0] + w, max_loc[1] + h),  # 右下角坐标 (根据滑块尺寸扩展)
              (0, 0, 255),                    # 矩形颜色 (红色)
              2)                              # 线条粗细

# 显示结果
cv2.imshow("Result", marked_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
max_loc
# Out:
# (231, 92)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.service import Service
import zipfile

PROXY_HOST = "adsl.proxy.acedata.cloud"
PROXY_PORT = 30005
PROXY_USER = "4c41328e"
PROXY_PASS = "ab0ab20f4c744240815604198c74eac4"

# 创建代理插件
def create_proxy_extension():
    manifest_json = """
    {
        "version": "1.0.0",
        "manifest_version": 2,
        "name": "Proxy Auth Extension",
        "permissions": ["proxy", "tabs", "unlimitedStorage", "storage", "<all_urls>", "webRequest", "webRequestBlocking"],
        "background": {
            "scripts": ["background.js"]
        },
        "minimum_chrome_version":"22.0.0"
    }
    """
    
    background_js = f"""
    var config = {{
            mode: "fixed_servers",
            rules: {{
                singleProxy: {{
                    scheme: "http",
                    host: "{PROXY_HOST}",
                    port: parseInt({PROXY_PORT})
                }},
                bypassList: ["localhost"]
            }}
        }};
    
    chrome.proxy.settings.set({{value: config, scope: "regular"}}, function() {{}});

    chrome.webRequest.onAuthRequired.addListener(
        function(details) {{
            return {{
                authCredentials: {{
                    username: "{PROXY_USER}",
                    password: "{PROXY_PASS}"
                }}
            }};
        }},
        {{urls: ["<all_urls>"]}},
        ["blocking"]
    );
    """
    
    # 创建插件文件
    plugin_file = "proxy_auth_plugin"
    with zipfile.ZipFile(f"{plugin_file}.zip", "w") as zip_file:
        zip_file.writestr("manifest.json", manifest_json)
        zip_file.writestr("background.js", background_js)
    
    return f"{plugin_file}.zip"

# 创建浏览器实例
options = webdriver.EdgeOptions()
options.add_extension('proxy_auth_plugin.zip')  # 添加代理扩展

# 启动浏览器
driver = webdriver.Edge(service=Service(), options=options)

# 访问目标网站
driver.get('https://ip.900cha.com/')  # 测试代理是否生效
# print(driver.page_source)

# driver.quit()
# Out:
# <html lang="zh-CN"><head>
#     <title>IP地址查询_本机IP_我的IP</title>
#     <meta charset="utf-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <meta name="description" content="IP地址查询是一个在线工具，访问本页面可以获取我当前的IP地址和本机IP，输入IP或者域名还可以查询对应的归属地信息，地理位置信息可以精确到运营商和国家、省市级别。">
#     <link rel="stylesheet" href="//cdn.staticfile.org/twitter-bootstrap/4.3.1/css/bootstrap.min.css">
#
#     <link rel="stylesheet" href="/css/common.css">
#     <link rel="shortcut icon" href="/favicon.ico">
#     <script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202503060101/show_ads_impl_fy2021.js"></script><script src="https://hm.baidu.com/hm.js?f2b7b31f146deaf06efb52986c06d478"></script><script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1865255241075286" crossorigin="anonymous" data-checked-head="true"></script>
# ...

# %%
from seleniumwire import webdriver  # selenium-wire 替代 selenium 导入
from selenium.webdriver.common.by import By

# 代理设置
proxy_username = '4c41328e'
proxy_password = 'ab0ab20f4c744240815604198c74eac4'
proxy_host = 'adsl.proxy.acedata.cloud'
proxy_port = 30005

# 启动浏览器并设置代理
options = {
    'proxy': {
        'http': f'http://{proxy_username}:{proxy_password}@{proxy_host}:{proxy_port}',
        'https': f'https://{proxy_username}:{proxy_password}@{proxy_host}:{proxy_port}'
    }
}

driver = webdriver.Edge(seleniumwire_options=options)

# 测试代理是否生效
driver.get("https://ip.900cha.com/")
# print(driver.page_source)

# driver.quit()
# Out:
# 127.0.0.1:58717: Traceback (most recent call last):
#   File "d:\ProgramData\miniforge3\lib\site-packages\seleniumwire\thirdparty\mitmproxy\net\tcp.py", line 94, in write
#     r = self.o.write(v)
#   File "d:\ProgramData\miniforge3\lib\socket.py", line 735, in write
#     return self._sock.send(b)
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "d:\ProgramData\miniforge3\lib\site-packages\seleniumwire\thirdparty\mitmproxy\server\server.py", line 113, in handle
#     root_layer()
#   File "d:\ProgramData\miniforge3\lib\site-packages\seleniumwire\thirdparty\mitmproxy\server\modes\http_proxy.py", line 23, in __call__
#     layer()
#   File "d:\ProgramData\miniforge3\lib\site-packages\seleniumwire\thirdparty\mitmproxy\server\protocol\tls.py", line 285, in __call__
#     layer()
# ...
